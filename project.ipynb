# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv(r'C:\Users\HP\Downloads\Telegram Desktop\covid-cases-omicron.csv')
print(data.shape)
print(data.head(10))
plot = data.groupby(['Entity']).sum().plot(kind='pie', y='Omicron_percentage', figsize=(10, 20))
# x=data['Entity']
# y=data['Omicron_percentage']
# plt.xlabel('Entity')
# plt.ylabel('Omicron_percentage')
# plt.bar(x,y)
# plt.show()
# Out:
# (552, 4)
#       Entity Code         Day  Omicron_percentage
# 0     Angola  AGO  2021-09-20                0.00
# 1     Angola  AGO  2021-10-04                0.00
# 2  Argentina  ARG  2021-09-20                0.00
# 3  Argentina  ARG  2021-10-04                0.00
# 4  Argentina  ARG  2021-10-18                0.00
# 5  Argentina  ARG  2021-11-01                0.00
# 6  Argentina  ARG  2021-11-15                0.00
# 7  Argentina  ARG  2021-11-29                0.00
# 8  Argentina  ARG  2021-12-13               14.94
# 9  Argentina  ARG  2021-12-27               85.11
